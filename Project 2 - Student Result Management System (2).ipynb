# %% [markdown]
# # 🎓 Student Result Management System
# This system stores and manages student marks.
# Features:
# - Add student
# - View student
# - Calculate percentage
# - Assign grade

# %%
students = {}

# %%
def calculate_grade(percentage):
    if percentage >= 90:
        return "A"
    elif percentage >= 75:
        return "B"
    elif percentage >= 60:
        return "C"
    elif percentage >= 40:
        return "D"
    else:
        return "Fail"

# %%
def add_student():
    roll = input("Enter Roll No: ")
    name = input("Enter Name: ")
    
    marks = []
    for i in range(3):
        m = float(input(f"Enter marks of subject {i+1}: "))
        marks.append(m)
    
    total = sum(marks)
    percentage = total / 3
    grade = calculate_grade(percentage)
    
    students[roll] = {
        "Name": name,
        "Marks": marks,
        "Total": total,
        "Percentage": percentage,
        "Grade": grade
    }

# %%
def view_students():
    for roll,data in students.items():
        print("\nRoll:", roll)
        for key,value in data.items():
            print(key,":",value)

# %%
def run_result_system():
    while True:
        print("\n1.Add Student 2.View Students 3.Exit")
        ch = input("Choice: ")
        
        if ch == '1':
            add_student()
        elif ch == '2':
            view_students()
        elif ch == '3':
            break
        else:
            print("Invalid")

# %%
run_result_system()
# Out:
# 1.Add Student 2.View Students 3.Exit
# Choice:  1
# Enter Roll No:  42
# Enter Name:  Sakshi Muthiyan
# Enter marks of subject 1:  88
# Enter marks of subject 2:  90
# Enter marks of subject 3:  95
# 1.Add Student 2.View Students 3.Exit
# Choice:  1
# Enter Roll No:  43
# Enter Name:  Nidhi Pipada
# Enter marks of subject 1:  85
# Enter marks of subject 2:  89
# Enter marks of subject 3:  91
# 1.Add Student 2.View Students 3.Exit
# Choice:  1
# Enter Roll No:  44
# Enter Name:  Diya Darda
# Enter marks of subject 1:  86
# Enter marks of subject 2:  84
# Enter marks of subject 3:  77
# 1.Add Student 2.View Students 3.Exit
# Choice:  2
# Roll: 42
# Name : Sakshi Muthiyan
# Marks : [88.0, 90.0, 95.0]
# Total : 273.0
# Percentage : 91.0
# Grade : A
#
# Roll: 43
# Name : Nidhi Pipada
# Marks : [85.0, 89.0, 91.0]
# Total : 265.0
# Percentage : 88.33333333333333
# Grade : B
#
# Roll: 44
# Name : Diya Darda
# Marks : [86.0, 84.0, 77.0]
# Total : 247.0
# Percentage : 82.33333333333333
# ...

# %%
print("===== STUDENT RESULT MANAGEMENT SYSTEM =====")

students = []

# Function to calculate grade
def calculate_grade(percentage):
    if percentage >= 90:
        return "A+"
    elif percentage >= 80:
        return "A"
    elif percentage >= 70:
        return "B"
    elif percentage >= 60:
        return "C"
    elif percentage >= 50:
        return "D"
    else:
        return "F"

# ----------- DEMO ENTRIES (for GitHub Output) -----------

print("\nChoice: 1 (Add Student)")
print("Enter Roll No: 42")
print("Enter Name: Sakshi Muthiyan")
print("Marks: 88, 90, 95")

marks1 = [88, 90, 95]
total1 = sum(marks1)
per1 = total1/3
students.append([42, "Sakshi Muthiyan", marks1, total1, per1, calculate_grade(per1)])

print("\nChoice: 1 (Add Student)")
print("Enter Roll No: 43")
print("Enter Name: Nidhi Pipada")
print("Marks: 75, 83, 91")

marks2 = [75, 83, 91]
total2 = sum(marks2)
per2 = total2/3
students.append([43, "Nidhi Pipada", marks2, total2, per2, calculate_grade(per2)])

print("\nChoice: 1 (Add Student)")
print("Enter Roll No: 44")
print("Enter Name: Diya Darda")
print("Marks: 86, 84, 77")

marks3 = [86, 84, 77]
total3 = sum(marks3)
per3 = total3/3
students.append([44, "Diya Darda", marks3, total3, per3, calculate_grade(per3)])

# ----------- VIEW STUDENTS -----------

print("\nChoice: 2 (View Students)\n")

for s in students:
    print("Roll No:", s[0])
    print("Name:", s[1])
    print("Marks:", s[2])
    print("Total:", s[3])
    print("Percentage:", round(s[4],2))
    print("Grade:", s[5])
    print("-----------------------------")

print("\nChoice: 3 (Exit)")
print("System Closed Successfully")
# Out:
# ===== STUDENT RESULT MANAGEMENT SYSTEM =====
#
# Choice: 1 (Add Student)
# Enter Roll No: 42
# Enter Name: Sakshi Muthiyan
# Marks: 88, 90, 95
#
# Choice: 1 (Add Student)
# Enter Roll No: 43
# Enter Name: Nidhi Pipada
# Marks: 75, 83, 91
#
# Choice: 1 (Add Student)
# Enter Roll No: 44
# Enter Name: Diya Darda
# Marks: 86, 84, 77
#
# Choice: 2 (View Students)
#
# Roll No: 42
# Name: Sakshi Muthiyan
# Marks: [88, 90, 95]
# Total: 273
# Percentage: 91.0
# Grade: A+
# -----------------------------
# Roll No: 43
# Name: Nidhi Pipada
# Marks: [75, 83, 91]
# Total: 249
# Percentage: 83.0
# Grade: A
# -----------------------------
# Roll No: 44
# Name: Diya Darda
# Marks: [86, 84, 77]
# Total: 247
# Percentage: 82.33
# Grade: A
# -----------------------------
#
# Choice: 3 (Exit)
# System Closed Successfully

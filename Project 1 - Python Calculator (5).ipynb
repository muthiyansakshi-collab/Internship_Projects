# %% [markdown]
# # 🧮 Python Based Calculator
# This project demonstrates a menu-driven calculator built using Python.
# It performs:
# - Addition
# - Subtraction
# - Multiplication
# - Division
#
# Concepts Used:
# - Functions
# - Loops
# - Conditional Statements
# - Exception Handling

# %%
# Arithmetic Functions

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error! Division by zero not allowed"
    return a / b

# %%
def run_calculator():
    while True:
        print("\n--- Python Calculator ---")
        print("1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit")
        
        choice = input("Enter choice: ")

        if choice == '5':
            print("Calculator Closed")
            break
        
        if choice not in ['1','2','3','4']:
            print("Invalid Choice!")
            continue
        
        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))

            if choice == '1':
                print("Result:", add(num1,num2))
            elif choice == '2':
                print("Result:", subtract(num1,num2))
            elif choice == '3':
                print("Result:", multiply(num1,num2))
            elif choice == '4':
                print("Result:", divide(num1,num2))

        except:
            print("Please enter valid numbers!")

# %%
run_calculator()
# Out:
# --- Python Calculator ---
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit
# Enter choice:  1
# Enter first number:  89
# Enter second number:  95
# Result: 184.0
#
# --- Python Calculator ---
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit
# Enter choice:  2
# Enter first number:  49
# Enter second number:  40
# Result: 9.0
#
# --- Python Calculator ---
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit
# Enter choice:  3
# Enter first number:  89
# Enter second number:  7
# Result: 623.0
#
# --- Python Calculator ---
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit
# Enter choice:  4
# Enter first number:  555
# Enter second number:  35
# Result: 15.857142857142858
#
# --- Python Calculator ---
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit
# Enter choice:  7
# Invalid Choice!
#
# --- Python Calculator ---
# 1.Add  2.Subtract  3.Multiply  4.Divide  5.Exit
# Enter choice:  5
# Calculator Closed

# %%
# Sample Run Demonstration (for GitHub display)

print("--- Python Calculator ---")

print("\nUser Choice: 1 (Addition)")
print("First Number Entered: 10")
print("Second Number Entered: 5")
print("Output:", add(10,5))

print("\nUser Choice: 2 (Subtraction)")
print("First Number Entered: 20")
print("Second Number Entered: 8")
print("Output:", subtract(20,8))

print("\nUser Choice: 3 (Multiplication)")
print("First Number Entered: 6")
print("Second Number Entered: 7")
print("Output:", multiply(6,7))

print("\nUser Choice: 4 (Division)")
print("First Number Entered: 50")
print("Second Number Entered: 5")
print("Output:", divide(50,5))

print("\nUser Choice: 7")
print("Output:Invalid Choice!")

print("\nUser Choice: 5 (Exit)")
print("Output:Calculator Closed")
# Out:
# --- Python Calculator ---
#
# User Choice: 1 (Addition)
# First Number Entered: 10
# Second Number Entered: 5
# Output: 15
#
# User Choice: 2 (Subtraction)
# First Number Entered: 20
# Second Number Entered: 8
# Output: 12
#
# User Choice: 3 (Multiplication)
# First Number Entered: 6
# Second Number Entered: 7
# Output: 42
#
# User Choice: 4 (Division)
# First Number Entered: 50
# Second Number Entered: 5
# Output: 10.0
#
# User Choice: 7
# Output:Invalid Choice!
#
# User Choice: 5 (Exit)
# Output:Calculator Closed
